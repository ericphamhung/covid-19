# %%
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd


from datetime import datetime, date
from dateutil.relativedelta import relativedelta

import warnings
warnings.filterwarnings('ignore')

# %%
# getting s&p data for sp500 and sp1000 (sp400 + sp600)
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies#S&P_500_component_stocks'
url2 = 'https://en.wikipedia.org/wiki/List_of_S%26P_1000_companies'
sp500 = pd.read_html(url)[0]
sp500.columns = [c.lower() for c in sp500.columns]
sp1000 = pd.read_html(url2)[5]
sp1000.columns = [c.lower() for c in sp1000.columns]

# checking and removing overlap
sp500_s = [s for s in sp500['symbol']]
sp1000_s = [s for s in sp1000['ticker symbol']]

duplicates = [s for s in sp1000_s if s in sp500_s]

sp1000 = sp1000[~sp1000['ticker symbol'].isin(duplicates)]

# fixing columns
cols_500 = {'symbol':'symbol','security':'name', 'gics sector':'sector', 'gics sub industry':'industry'}
cols_1000 =  {'company':'name', 'ticker symbol' : 'symbol', 'gics economic sector':'sector', 'gics sub-industry':'industry'}

sp500.rename(columns = cols_500, inplace=True)
sp1000.rename(columns = cols_1000, inplace=True)

columns = ['name', 'symbol','sector','industry']

sp1000 = sp1000[columns]
sp500 = sp500[columns]

# merging dataframes
sp1500 = pd.concat([sp1000,sp500])

#ticker list
tick_list = [s for s in sp1500['symbol']]

# %%
tick_string = ' '
tick_string = tick_string.join(tick_list)

# %%
import yfinance as yf

data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = tick_string,

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "2y",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1mo",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = False,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# %time
# Out:
# [*********************100%***********************]  1481 of 1481 completed
#
# 65 Failed downloads:
# - NAVG: No data found, symbol may be delisted
# - CLD: No data found, symbol may be delisted
# - EGL: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted
# - CVG: No data found for this date range, symbol may be delisted
# - AHL: No data found for this date range, symbol may be delisted
# - ESIO: No data found for this date range, symbol may be delisted
# - PERY: No data found for this date range, symbol may be delisted
# - CRAY: No data found, symbol may be delisted
# - OCLR: No data found for this date range, symbol may be delisted
# - MOG.A: No data found, symbol may be delisted
# - TTS: No data found, symbol may be delisted
# - ULTI: No data found, symbol may be delisted
# - CJ: No data found, symbol may be delisted
# - NCI: No data found, symbol may be delisted
# - KS: No data found for this date range, symbol may be delisted
# - MDSO: No data found, symbol may be delisted
# - VVC: No data found for this date range, symbol may be delisted
# - FNSR: No data found, symbol may be delisted
# - GNBC: No data found for this date range, symbol may be delisted
# - LHO: No data found for this date range, symbol may be delisted
# - LABL: No data found, symbol may be delisted
# - BABY: No data found, symbol may be delisted
# - ISCA: No data found, symbol may be delisted
# - HPT: No data found, symbol may be delisted
# - KLXI: No data found for this date range, symbol may be delisted
# - XOXO: No data found for this date range, symbol may be delisted
# - VSM: No data found, symbol may be delisted
# - EGN: No data found for this date range, symbol may be delisted
# - LPNT: No data found for this date range, symbol may be delisted
# - BEL: No data found, symbol may be delisted
# - NANO: No data found, symbol may be delisted
# - ESND: No data found for this date range, symbol may be delisted
# - SRCI: No data found, symbol may be delisted
# - LTXB: No data found, symbol may be delisted
# - LION: No data found, symbol may be delisted
# - BMS: No data found, symbol may be delisted
# - PAY: No data found for this date range, symbol may be delisted
# - BID: No data found, symbol may be delisted
# - EFII: No data found, symbol may be delisted
# - ILG: No data found for this date range, symbol may be delisted
# - DF: No data found, symbol may be delisted
# - SFLY: No data found, symbol may be delisted
# - DSW: No data found, symbol may be delisted
# - BKS: No data found, symbol may be delisted
# - PES: No data found, symbol may be delisted
# - EDR: No data found, symbol may be delisted
# - GOV: No data found for this date range, symbol may be delisted
# - ITG: No data found, symbol may be delisted
# - CHSP: No data found, symbol may be delisted
# - ACXM: No data found for this date range, symbol may be delisted
# - HYH: No data found for this date range, symbol may be delisted
# - SONC: No data found for this date range, symbol may be delisted
# - BOFI: No data found for this date range, symbol may be delisted
# - TYPE: No data found, symbol may be delisted
# - ATU: No data found, symbol may be delisted
# - BRS: No data found, symbol may be delisted
# - RTEC: No data found, symbol may be delisted
# - WAGE: No data found, symbol may be delisted
# - SVU: No data found for this date range, symbol may be delisted
# - CTRL: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted
# - JW.A: No data found, symbol may be delisted
# - HBHC: No data found for this date range, symbol may be delisted
# - ESL: No data found, symbol may be delisted

# %%
data
# Out:
#            NAVG                                       NBR                      \
#            Open High Low Close Adj Close Volume      Open      High       Low
# Date
# 2018-04-01  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-05-01  NaN  NaN NaN   NaN       NaN    NaN  6.950329  8.198060  6.543660
# 2018-05-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-06-01  NaN  NaN NaN   NaN       NaN    NaN  6.922601  7.088966  5.591687
# 2018-06-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-07-01  NaN  NaN NaN   NaN       NaN    NaN  5.936645  6.374671  5.284266
# 2018-07-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-08-01  NaN  NaN NaN   NaN       NaN    NaN  5.498619  6.383990  5.368144
# 2018-08-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-09-01  NaN  NaN NaN   NaN       NaN    NaN  5.768890  6.048481  5.274946
# 2018-09-19  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-10-01  NaN  NaN NaN   NaN       NaN    NaN  5.838399  6.262154  4.228131
# 2018-10-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-11-01  NaN  NaN NaN   NaN       NaN    NaN  4.708386  5.480562  2.975700
# 2018-11-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2018-12-01  NaN  NaN NaN   NaN       NaN    NaN  3.154619  3.182869  1.704436
# 2018-12-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-01-01  NaN  NaN NaN   NaN       NaN    NaN  1.875340  3.019779  1.827255
# 2019-01-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-02-01  NaN  NaN NaN   NaN       NaN    NaN  2.856288  3.212121  2.596625
# 2019-02-19  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-03-01  NaN  NaN NaN   NaN       NaN    NaN  3.125567  3.577572  2.981310
# 2019-03-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-04-01  NaN  NaN NaN   NaN       NaN    NaN  3.395842  3.936089  3.318663
# 2019-04-18  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-05-01  NaN  NaN NaN   NaN       NaN    NaN  3.202896  3.849264  2.074165
# 2019-05-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-06-01  NaN  NaN NaN   NaN       NaN    NaN  2.296052  2.817005  1.910161
# 2019-06-19  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-07-01  NaN  NaN NaN   NaN       NaN    NaN  2.945306  2.993748  1.928013
# 2019-07-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-08-01  NaN  NaN NaN   NaN       NaN    NaN  2.799978  2.799978  1.550161
# 2019-08-21  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-09-01  NaN  NaN NaN   NaN       NaN    NaN  1.637357  2.683716  1.579226
# 2019-09-19  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-10-01  NaN  NaN NaN   NaN       NaN    NaN  1.849146  2.131384  1.459852
# 2019-10-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-11-01  NaN  NaN NaN   NaN       NaN    NaN  1.829681  2.160581  1.722625
# 2019-11-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2019-12-01  NaN  NaN NaN   NaN       NaN    NaN  1.995131  3.221406  1.878342
# 2019-12-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2020-01-01  NaN  NaN NaN   NaN       NaN    NaN  2.853636  3.273864  2.003409
# 2020-01-22  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2020-02-01  NaN  NaN NaN   NaN       NaN    NaN  1.983864  2.325909  1.465909
# 2020-02-19  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2020-03-01  NaN  NaN NaN   NaN       NaN    NaN  1.749318  1.798182  0.302955
# 2020-03-20  NaN  NaN NaN   NaN       NaN    NaN       NaN       NaN       NaN
# 2020-04-01  NaN  NaN NaN   NaN       NaN    NaN  0.390000  0.430000  0.260000
# 2020-04-21  NaN  NaN NaN   NaN       NaN    NaN  0.248000  0.248000  0.220000
#
#                       ...       FAST                                   \
#                Close  ...       Open       High        Low      Close
# Date                  ...
# 2018-04-01       NaN  ...        NaN        NaN        NaN        NaN
# 2018-05-01  6.904116  ...  23.698182  25.564480  22.826612  25.213957
# 2018-05-22       NaN  ...        NaN        NaN        NaN        NaN
# 2018-06-01  5.924416  ...  25.375006  26.033421  22.783979  22.798191
# 2018-06-20       NaN  ...        NaN        NaN        NaN        NaN
# 2018-07-01  5.573177  ...  22.547140  27.696037  22.438194  26.966570
# 2018-07-20       NaN  ...        NaN        NaN        NaN        NaN
# 2018-08-01  5.750251  ...  27.130315  29.162226  26.305149  27.836237
# 2018-08-22       NaN  ...        NaN        NaN        NaN        NaN
# 2018-09-01  5.740931  ...  27.688375  28.403837  27.077848  27.674067
# 2018-09-19       NaN  ...        NaN        NaN        NaN        NaN
# 2018-10-01  4.680136  ...  27.869627  28.007950  22.899551  24.521265
# 2018-10-22       NaN  ...        NaN        NaN        NaN        NaN
# 2018-11-01  3.041618  ...  24.818817  28.765407  24.362146  28.486597
# 2018-11-20       NaN  ...        NaN        NaN        NaN        NaN
# 2018-12-01  1.883355  ...  28.842319  29.058637  23.655508  25.136082
# 2018-12-20       NaN  ...        NaN        NaN        NaN        NaN
# 2019-01-01  2.846670  ...  24.664991  29.255727  23.886247  29.063444
# 2019-01-22       NaN  ...        NaN        NaN        NaN        NaN
# 2019-02-01  3.115950  ...  29.404068  30.851758  28.958626  30.474098
# 2019-02-19       NaN  ...        NaN        NaN        NaN        NaN
# 2019-03-01  3.308293  ...  30.682295  31.248783  29.331443  31.137421
# 2019-03-20       NaN  ...        NaN        NaN        NaN        NaN
# 2019-04-01  3.376547  ...  31.447297  34.802644  31.035747  34.158691
# 2019-04-18       NaN  ...        NaN        NaN        NaN        NaN
# 2019-05-01  2.276757  ...  34.602561  34.798638  29.391835  29.989868
# 2019-05-22       NaN  ...        NaN        NaN        NaN        NaN
# 2019-06-01  2.797711  ...  29.421248  32.587882  29.421248  31.950632
# 2019-06-19       NaN  ...        NaN        NaN        NaN        NaN
# 2019-07-01  2.867798  ...  32.274157  32.440824  28.862432  30.195749
# 2019-07-22       NaN  ...        NaN        NaN        NaN        NaN
# 2019-08-01  1.627669  ...  30.446332  30.703014  28.017733  30.229141
# 2019-08-21       NaN  ...        NaN        NaN        NaN        NaN
# 2019-09-01  1.811750  ...  29.923098  33.654848  29.143183  32.252972
# 2019-09-19       NaN  ...        NaN        NaN        NaN        NaN
# 2019-10-01  1.800484  ...  32.578758  37.317486  29.755265  35.481228
# 2019-10-22       NaN  ...        NaN        NaN        NaN        NaN
# 2019-11-01  2.004863  ...  36.047215  37.646004  34.676824  35.272648
# 2019-11-20       NaN  ...        NaN        NaN        NaN        NaN
# 2019-12-01  2.802915  ...  35.133621  37.675792  33.793020  36.692688
# 2019-12-20       NaN  ...        NaN        NaN        NaN        NaN
# 2020-01-01  2.022954  ...  36.821784  37.338160  34.388845  34.637104
# 2020-01-22       NaN  ...        NaN        NaN        NaN        NaN
# 2020-02-01  1.720000  ...  35.209999  39.310001  33.490002  34.220001
# 2020-02-19       NaN  ...        NaN        NaN        NaN        NaN
# 2020-03-01  0.381136  ...  34.330002  36.389999  26.719999  31.250000
# 2020-03-20       NaN  ...        NaN        NaN        NaN        NaN
# 2020-04-01  0.270000  ...  30.170000  36.919998  29.920000  34.919998
# 2020-04-21  0.220100  ...  34.490002  34.814999  33.959999  34.139999
#
#                                CINF                                      \
#                  Volume        Open        High         Low       Close
# Date
# 2018-04-01          NaN         NaN         NaN         NaN         NaN
# 2018-05-01   91021400.0   66.705983   68.710393   64.863064   65.898521
# 2018-05-22          NaN         NaN         NaN         NaN         NaN
# 2018-06-01  104364800.0   66.468477   67.893412   63.010635   63.514111
# 2018-06-20          NaN         NaN         NaN         NaN         NaN
# 2018-07-01  182358000.0   63.737714   73.722460   63.718564   72.401367
# 2018-07-20          NaN         NaN         NaN         NaN         NaN
# 2018-08-01   87842600.0   72.363076   73.971357   70.448455   73.396973
# 2018-08-22          NaN         NaN         NaN         NaN         NaN
# 2018-09-01   77623200.0   73.224644   76.268890   72.611966   73.530983
# 2018-09-19          NaN         NaN         NaN         NaN         NaN
# 2018-10-01  182389800.0   74.324241   76.820668   68.444618   75.798965
# 2018-10-22          NaN         NaN         NaN         NaN         NaN
# 2018-11-01  148892600.0   75.635108   79.172520   74.623039   78.777336
# 2018-11-20          NaN         NaN         NaN         NaN         NaN
# 2018-12-01  104269400.0   79.529156   81.061711   68.637389   74.623039
# 2018-12-20          NaN         NaN         NaN         NaN         NaN
# 2019-01-01  143993200.0   74.342651   79.030316   72.071613   78.729454
# 2019-01-22          NaN         NaN         NaN         NaN         NaN
# 2019-02-01   81483000.0   78.777975   84.591459   76.429292   84.261475
# 2019-02-19          NaN         NaN         NaN         NaN         NaN
# 2019-03-01   46579700.0   84.775858   84.882617   80.554051   83.368591
# 2019-03-20          NaN         NaN         NaN         NaN         NaN
# 2019-04-01   47517200.0   84.355130   94.085032   82.860478   93.958038
# 2019-04-18          NaN         NaN         NaN         NaN         NaN
# 2019-05-01   71478000.0   94.251109   97.767940   92.170312   95.970444
# 2019-05-22          NaN         NaN         NaN         NaN         NaN
# 2019-06-01   78540200.0   96.234212  103.941936   95.745763  101.275002
# 2019-06-19          NaN         NaN         NaN         NaN         NaN
# 2019-07-01  109815500.0  102.668716  107.235918  101.627593  105.418861
# 2019-07-22          NaN         NaN         NaN         NaN         NaN
# 2019-08-01   91355700.0  105.261706  111.665614  101.372220  110.486977
# 2019-08-21          NaN         NaN         NaN         NaN         NaN
# 2019-09-01   80332500.0  110.496806  115.073833  107.746660  114.592552
# 2019-09-19          NaN         NaN         NaN         NaN         NaN
# 2019-10-01  141905200.0  115.381549  116.664776  108.254721  111.749039
# 2019-10-22          NaN         NaN         NaN         NaN         NaN
# 2019-11-01   68098700.0  112.055040  112.528849  104.266860  105.668541
# 2019-11-20          NaN         NaN         NaN         NaN         NaN
# 2019-12-01   66369300.0  105.599439  105.796855  101.364800  103.793053
# 2019-12-20          NaN         NaN         NaN         NaN         NaN
# 2020-01-01   98643600.0  104.812919  106.847250  102.034312  104.148033
# 2020-01-22          NaN         NaN         NaN         NaN         NaN
# 2020-02-01   78916400.0  105.031237  114.647195   91.406157   92.527519
# 2020-02-19          NaN         NaN         NaN         NaN         NaN
# 2020-03-01  179971700.0   93.281715  104.019036   65.188044   74.873459
# 2020-03-20          NaN         NaN         NaN         NaN         NaN
# 2020-04-01   71777100.0   71.940002   87.599998   70.550003   82.480003
# 2020-04-21    4507293.0   80.330002   81.860001   79.540001   80.169998
#
#
#                 Volume
# Date
# 2018-04-01         NaN
# 2018-05-01  11497400.0
# 2018-05-22         NaN
# 2018-06-01  10607900.0
# 2018-06-20         NaN
# 2018-07-01  12185100.0
# 2018-07-20         NaN
# 2018-08-01   8380300.0
# 2018-08-22         NaN
# 2018-09-01   8314300.0
# 2018-09-19         NaN
# 2018-10-01  16952200.0
# 2018-10-22         NaN
# 2018-11-01  14422000.0
# 2018-11-20         NaN
# 2018-12-01  12947600.0
# 2018-12-20         NaN
# 2019-01-01  15379900.0
# 2019-01-22         NaN
# 2019-02-01  14266400.0
# 2019-02-19         NaN
# 2019-03-01  12466300.0
# 2019-03-20         NaN
# 2019-04-01  12231900.0
# 2019-04-18         NaN
# 2019-05-01  16087400.0
# 2019-05-22         NaN
# 2019-06-01  17284800.0
# 2019-06-19         NaN
# 2019-07-01  15919100.0
# 2019-07-22         NaN
# 2019-08-01  13044500.0
# 2019-08-21         NaN
# 2019-09-01  11298800.0
# 2019-09-19         NaN
# 2019-10-01  14472800.0
# 2019-10-22         NaN
# 2019-11-01  13249100.0
# 2019-11-20         NaN
# 2019-12-01  11685400.0
# 2019-12-20         NaN
# 2020-01-01  11676300.0
# 2020-01-22         NaN
# 2020-02-01  15752900.0
# 2020-02-19         NaN
# 2020-03-01  29090300.0
# 2020-03-20         NaN
# 2020-04-01  12685000.0
# 2020-04-21    549164.0
#
# [49 rows x 7572 columns]

# %%
tick='DAL'
plt.plot(data[tick]['Close'])
plt.xticks(rotation=90)
plt.title(tick)
plt.show()

# %%
# latest_date = str(data.index[-3])
latest_date = '2020-04-09'
# lastyear_date = data.index[-3] + relativedelta(years=-1)
lastyear_date = '2019-04-08'

print(data[tick].loc[lastyear_date]['Close'])

print(data[tick].loc[latest_date]['Close'])
# latest_date
# Out:
# 56.52095413208008
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2601             try:
# -> 2602                 return self._engine.get_loc(key)
#    2603             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine._date_check_type()
#
# KeyError: '2020-04-09'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     998         try:
# --> 999             return Index.get_loc(self, key, method, tolerance)
#    1000         except (KeyError, ValueError, TypeError):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2603             except KeyError:
# -> 2604                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2605         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine._date_check_type()
#
# KeyError: '2020-04-09'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1586390400000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2601             try:
# -> 2602                 return self._engine.get_loc(key)
#    2603             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2020-04-09 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1586390400000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#    1011                     stamp = stamp.tz_localize(self.tz)
# -> 1012                 return Index.get_loc(self, stamp, method, tolerance)
#    1013             except KeyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2603             except KeyError:
# -> 2604                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2605         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2020-04-09 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-2b251e5333e0> in <module>()
#       6 print(data[tick].loc[lastyear_date]['Close'])
#       7
# ----> 8 print(data[tick].loc[latest_date]['Close'])
#       9 # latest_date
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3573                                                       drop_level=drop_level)
#    3574         else:
# -> 3575             loc = self.index.get_loc(key)
#    3576
#    3577             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#    1012                 return Index.get_loc(self, stamp, method, tolerance)
#    1013             except KeyError:
# -> 1014                 raise KeyError(key)
#    1015             except ValueError as e:
#    1016                 # list-like tolerance size must match target index size
#
# KeyError: '2020-04-09'

# %%
# tick='UAL'
# info = yf.Ticker(tick)
# # info.info['sharesOutstanding']
# info.balance_sheet

# %%
def get_change(tick):
    pre = data[tick].loc[lastyear_date]['Close']
    post = data[tick].loc[latest_date]['Close']
    return (post-pre)/pre

def get_pre(tick):
    return data[tick].loc[lastyear_date]['Close']

def get_post(tick):
    return data[tick].loc[latest_date]['Close']

def get_so(tick):
    info = yf.Ticker(tick)
    try:
        shares = info.info['sharesOutstanding']
    except:
        shares = 0
        pass
    return shares

def get_mcap(tick):
    return

# %%
get_pre('UAL')
# Out:
# 85.48999786376953

# %%
len(sp1500['sector'].unique())
# Out:
# 14

# %%
sector = 'Industrials'
temp_ = sp1500[sp1500['sector']==sector]


for t in temp_['industry'].unique():
    print(t)

    print('start')
    temp_['pre'] = temp_['symbol'].apply(get_pre)
    print('pre')
    temp_['post'] = temp_['symbol'].apply(get_post)
    print('post')
    temp_['shares_out'] = temp_['symbol'].apply(get_so)
    print('so')
    temp_['pre_mktcap'] = temp_[['pre','shares_out']].product(axis=1)
    print('premkt')
    temp_['post_mktcap'] = temp_[['post','shares_out']].product(axis=1)
    print('postmkt')
    print('{:,}'.format(temp_['pre_mktcap'].sum()))
    print('{:,}'.format(temp_['post_mktcap'].sum()))
#     break
# Out:
# Building Products
# start
# pre
# post
# so
# premkt
# postmkt
# 1,919,049,101,115.1636
# 1,595,454,354,620.6035
# Air Freight and Logistics
# start
# pre
# post
# so
# premkt
# postmkt
# 2,032,407,108,872.4736
# 1,596,728,910,279.2131
# Aerospace and Defense
# start
# pre
# post
# so
# premkt
# postmkt
# 2,068,451,887,873.6877
# 1,627,425,640,044.4678
# Environmental and Facilities Services
# start
# pre
# post
# so
# premkt
# postmkt
# 2,051,137,458,862.7935
# 1,709,071,218,064.1318
# Construction & Engineering
# start
# pre
# post
# so
# premkt
# postmkt
# 1,963,970,183,873.7249
# 1,629,536,719,710.2998
# Construction and Engineering
# start
# pre
# post
# so
# premkt
# postmkt
# 2,022,110,674,327.8452
# 1,677,856,585,832.5151
# Construction & Farm Equipment & Heavy Trucks
# start
# pre
# post
# so
# premkt
# postmkt
# 1,957,639,393,315.525
# 1,625,320,587,087.1848
# Industrial Machinery
# start
# pre
# post
# so
# premkt
# postmkt
# 1,942,355,452,816.0447
# 1,620,492,510,647.3477
# Trading Companies and Distributors
# start
# pre
# post
# so
# premkt
# postmkt
# 1,944,135,318,931.8643
# 1,612,391,455,119.3755
# Construction Machinery and Heavy Trucks
# start
# pre
# post
# so
# premkt
# postmkt
# 2,105,005,587,838.112
# 1,658,838,867,139.9172
# Airlines
# start
# pre
# post
# so
# premkt
# postmkt
# 2,006,182,392,374.744
# 1,672,694,885,373.5312
# Trucking
# start
# pre
# post
# so
# premkt
# postmkt
# 1,942,598,891,988.721
# 1,610,880,984,330.6428
# Human Resource and Employment Services
# start
# pre
# post
# so
# premkt
# postmkt
# 1,994,883,635,272.8474
# 1,666,322,237,637.1313
# Electrical Components & Equipment
# start
# pre
# post
# so
# premkt
# postmkt
# 1,951,607,934,403.251
# 1,622,832,497,032.1606
# Heavy Electrical Equipment
# start
# pre
# post
# so
# premkt
# postmkt
# 1,919,049,101,115.1636
# 1,595,454,354,620.6035
# Security & Alarm Services
# start
# pre
# post
# so
# premkt
# postmkt
# 1,918,297,791,497.8184
# 1,594,183,888,076.1047
# Commercial Printing
# start
# pre
# post
# so
# premkt
# postmkt
# 1,954,717,363,760.0945
# 1,625,643,287,554.5845
# Environmental & Facilities Services
# start
# pre
# post
# so
# premkt
# postmkt
# 2,068,292,571,987.8577
# 1,622,566,916,152.4429
# Industrial Conglomerates
# start
# pre
# post
# so
# premkt
# postmkt
# 1,950,494,622,251.9722
# 1,619,245,433,216.5542
# Aerospace & Defense
# start
# pre
# post
# so
# premkt
# postmkt
# 1,997,439,690,161.6167
# 1,665,306,777,783.81
# Research & Consulting Services
# start
# pre
# post
# so
# premkt
# postmkt
# 2,046,951,228,139.915
# 1,707,730,550,437.8667
# Trading Companies & Distributors
# start
# pre
# post
# so
# premkt
# postmkt
# 1,950,572,586,012.4453
# 1,626,952,286,552.814
# Office Services and Supplies
# start
# pre
# post
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4e85f333c4be> in <module>()
#      11     temp_['post'] = temp_['symbol'].apply(get_post)
#      12     print('post')
# ---> 13     temp_['shares_out'] = temp_['symbol'].apply(get_so)
#      14     print('so')
#      15     temp_['pre_mktcap'] = temp_[['pre','shares_out']].product(axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-66fe834276ac> in get_so(tick)
#      16     except:
#      17         shares = 0
# ---> 18         pass
#      19     return shares
#      20
#
# KeyboardInterrupt:

# %%
len(temp_['industry'].unique())
# %timeit
